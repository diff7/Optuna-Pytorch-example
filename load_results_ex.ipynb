# %%
import optuna
import matplotlib.pyplot as plt
import seaborn as sns

# %%
study = optuna.study.load_study(study_name='TEST_MLP', storage='sqlite:///example.db')
df = study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))

# %%
study.best_params
# Out:
# {'dropout_l0': 0.20150823995290362,
#  'lr': 0.005695467684494286,
#  'n_layers': 1,
#  'n_units_l0': 114,
#  'optimizer': 'Adam'}

# %%
study.best_value
# Out:
# 0.96015625

# %%
plt.figure(figsize=(10,5))
df = study.trials_dataframe(attrs=('number', 'value', 'params', 'state'))
sns.scatterplot(df.params_lr, df.value, hue=df.params_optimizer)
